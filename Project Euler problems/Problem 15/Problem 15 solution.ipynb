# %%
def lattice(x,y):
    if x==1:
        return 1
    elif y==1:
        return 1
    else:
        return lattice(x-1,y) + lattice(x,y-1)
    
n = 20
print(lattice(n,n))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a584d45e57aa> in <module>
#       8
#       9 n = 20
# ---> 10 print(lattice(n,n))
#
# <ipython-input-2-a584d45e57aa> in lattice(x, y)
#       5         return 1
#       6     else:
# ----> 7         return lattice(x-1,y) + lattice(x,y-1)
#       8
#       9 n = 20
#
# <ipython-input-2-a584d45e57aa> in lattice(x, y)
#       5         return 1
#       6     else:
# ----> 7         return lattice(x-1,y) + lattice(x,y-1)
#       8
#       9 n = 20
#
# <ipython-input-2-a584d45e57aa> in lattice(x, y)
#       5         return 1
#       6     else:
# ----> 7         return lattice(x-1,y) + lattice(x,y-1)
#       8
#       9 n = 20
#
# <ipython-input-2-a584d45e57aa> in lattice(x, y)
#       5         return 1
#       6     else:
# ----> 7         return lattice(x-1,y) + lattice(x,y-1)
#       8
#       9 n = 20
#
# ...

# %%
grid = []
for i in range(21):
    if i==0:
        grid.append([1]*21)
        grid[-1][0] = 1
for i in range(1,21):
    for j in range(1,21):
        grid[i][j] = grid [i][j-1] + grid [i-1][j]
print(grid[-1][-1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-19b67aa09ac6> in <module>
#       6 for i in range(1,21):
#       7     for j in range(1,21):
# ----> 8         grid[i][j] = grid [i][j-1] + grid [i-1][j]
#       9 print(grid[-1][-1])
#
# IndexError: list index out of range
